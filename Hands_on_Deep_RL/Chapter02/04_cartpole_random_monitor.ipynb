# %%
if 1:
  # !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1

# %%
if 1:
  # !apt-get install x11-utils > /dev/null 2>&1 
  # !pip install pyglet > /dev/null 2>&1 
  # !apt-get install -y xvfb python-opengl > /dev/null 2>&1
  # !pip install gym pyvirtualdisplay > /dev/null 2>&1

# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
from IPython import display as ipythondisplay

# %%
gym.__version__
# Out:
# '0.17.3'

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(400, 300))
display.start()

# %%
rm -rf recording

# %%
env = gym.make("CartPole-v0")
env = gym.wrappers.Monitor(env, "recording")

total_reward = 0.0
total_steps = 0
obs = env.reset()

while True:
    action = env.action_space.sample()
    obs, reward, done, _ = env.step(action)
    total_reward += reward
    total_steps += 1
    print(f'total_steps: {total_steps}, total_reward: {total_reward}')
    if done:
        break

print("Episode done in %d steps, total reward %.2f" % (
    total_steps, total_reward))
env.close()
env.env.close()
# Out:
# total_steps: 1, total_reward: 1.0
# total_steps: 2, total_reward: 2.0
# total_steps: 3, total_reward: 3.0
# total_steps: 4, total_reward: 4.0
# total_steps: 5, total_reward: 5.0
# total_steps: 6, total_reward: 6.0
# total_steps: 7, total_reward: 7.0
# total_steps: 8, total_reward: 8.0
# total_steps: 9, total_reward: 9.0
# total_steps: 10, total_reward: 10.0
# total_steps: 11, total_reward: 11.0
# total_steps: 12, total_reward: 12.0
# total_steps: 13, total_reward: 13.0
# total_steps: 14, total_reward: 14.0
# total_steps: 15, total_reward: 15.0
# total_steps: 16, total_reward: 16.0
# total_steps: 17, total_reward: 17.0
# total_steps: 18, total_reward: 18.0
# total_steps: 19, total_reward: 19.0
# total_steps: 20, total_reward: 20.0
# total_steps: 21, total_reward: 21.0
# total_steps: 22, total_reward: 22.0
# total_steps: 23, total_reward: 23.0
# total_steps: 24, total_reward: 24.0
# total_steps: 25, total_reward: 25.0
# Episode done in 25 steps, total reward 25.00

# %%
# !dir recording
# Out:
# openaigym.episode_batch.0.63.stats.json
# openaigym.manifest.0.63.manifest.json
# openaigym.video.0.63.video000000.meta.json
# openaigym.video.0.63.video000000.mp4

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('./recording/openaigym.video.0.63.video000000.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
